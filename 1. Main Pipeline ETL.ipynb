# %% [markdown]
# #### Delete the WareHouse and Reload all the data

# %%
# %fs rm -r /user/hive/warehouse/

# %%
# %sql
drop table if exists weather_log_table;
drop table if exists raw_weather;
drop table if exists processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# #### Install the dotenv package to load the environment variables from the .env file

# %%
# %pip install python-dotenv
# Out:
# Python interpreter will be restarted.
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# Python interpreter will be restarted.

# %% [markdown]
# #### load the notebook files

# %%
# %run "/Users/ujjwal.baral3980@kistcollege.edu.np/log_table.utils"

# %%
# %run "/Users/ujjwal.baral3980@kistcollege.edu.np/Dim Date & Time table"

# %%
# %run "/Users/ujjwal.baral3980@kistcollege.edu.np/cities.utiles"

# %%
# %run "/Users/ujjwal.baral3980@kistcollege.edu.np/get_raw_weather_utils"

# %%
# %run "/Users/ujjwal.baral3980@kistcollege.edu.np/get_processed_weather_utils"

# %% [markdown]
# #### Run the Necessary Function Inside above Notebooks  ie log_table

# %%
create_log_table()
load_date()
load_time()
load_cities()
# Out:
# /databricks/spark/python/pyspark/pandas/namespace.py:1881: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   pd.date_range(

# %% [markdown]
# #### Fetch the Data from the API and Load it into the Database

# %%
df_raw = get_raw_weather('RAW', 'raw_weather')
df_processed = get_process_weather('PROCESSED', 'processed_weather', df_raw)

# %% [markdown]
# #### Check the data in the database

# %%
# %sql
select * from raw_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>List(10000, 20700, List(309.21, 307.13, 309.21, 309.21, 1000, 18, 1000, 918), List(null), List(NP, 1686094096, 1686143963), 1686134454, List(83.7667, 27.9833), Wāliṅ, List(List(803, Clouds, broken clouds, 04d)), 200, 1282616, List(null, 242, 3.28), stations)</td><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(308.68, 306.25, 308.68, 308.68, 998, 15, 998, 888), List(null), List(NP, 1686093933, 1686143741), 1686134455, List(84.5667, 27.7667), Upardang Gadhi, List(List(801, Clouds, few clouds, 02d)), 200, 1282621, List(null, 177, 3.38), stations)</td><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(309.62, 307.6, 309.62, 309.62, 1001, 18, 1001, 930), List(null), List(NP, 1686094429, 1686144335), 1686134462, List(82.2973, 28.131), Tulsīpur, List(List(802, Clouds, scattered clouds, 03d)), 200, 1282635, List(null, 249, 2.89), stations)</td><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(314.85, 312.93, 314.85, 314.85, 997, 14, 997, 976), List(null), List(NP, 1686093967, 1686143739), 1686134463, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 180, 2.7), stations)</td><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(316.03, 313.04, 316.03, 316.03, 997, 10, 997, 980), List(null), List(NP, 1686094658, 1686144665), 1686134456, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 243, 2.84), stations)</td><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(309.21, 307.13, 309.21, 309.21, 1000, 18, 1000, 918), List(null), List(NP, 1686094096, 1686143963), 1686134454, List(83.7667, 27.9833), Wāliṅ, List(List(803, Clouds, broken clouds, 04d)), 200, 1282616, List(null, 242, 3.28), stations)</td><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(308.68, 306.25, 308.68, 308.68, 998, 15, 998, 888), List(null), List(NP, 1686093933, 1686143741), 1686134455, List(84.5667, 27.7667), Upardang Gadhi, List(List(801, Clouds, few clouds, 02d)), 200, 1282621, List(null, 177, 3.38), stations)</td><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(309.62, 307.6, 309.62, 309.62, 1001, 18, 1001, 930), List(null), List(NP, 1686094429, 1686144335), 1686134462, List(82.2973, 28.131), Tulsīpur, List(List(802, Clouds, scattered clouds, 03d)), 200, 1282635, List(null, 249, 2.89), stations)</td><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(314.85, 312.93, 314.85, 314.85, 997, 14, 997, 976), List(null), List(NP, 1686093967, 1686143739), 1686134463, List(84.5, 27.6333), Tikoli, List(List(800, Clear, clear sky, 01d)), 200, 1282665, List(null, 180, 2.7), stations)</td><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr><tr><td>List(10000, 20700, List(316.03, 313.04, 316.03, 316.03, 997, 10, 997, 980), List(null), List(NP, 1686094658, 1686144665), 1686134456, List(81.1333, 28.5), Ṭikāpur, List(List(800, Clear, clear sky, 01d)), 200, 1282666, List(null, 243, 2.84), stations)</td><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr></tbody></table></div>

# %%
# %sql
select * from processed_weather;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dt</th><th>date</th><th>city_id</th><th>city_name</th><th>timezone</th><th>country</th><th>lat</th><th>lon</th><th>temp</th><th>temp_min</th><th>temp_max</th><th>pressure</th><th>humidity</th><th>visibility</th><th>wind_speed</th><th>wind_deg</th><th>wind_gust</th><th>clouds_all</th><th>load_run_id</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>1686134454</td><td>2023-06-07 10:40:54</td><td>1282616</td><td>Wāliṅ</td><td>20700</td><td>NP</td><td>27.9833</td><td>83.7667</td><td>309.21</td><td>309.21</td><td>309.21</td><td>1000</td><td>18</td><td>10000</td><td>null</td><td>242</td><td>3.28</td><td>null</td><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr><tr><td>1686134455</td><td>2023-06-07 10:40:55</td><td>1282621</td><td>Upardang Gadhi</td><td>20700</td><td>NP</td><td>27.7667</td><td>84.5667</td><td>308.68</td><td>308.68</td><td>308.68</td><td>998</td><td>15</td><td>10000</td><td>null</td><td>177</td><td>3.38</td><td>null</td><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr><tr><td>1686134462</td><td>2023-06-07 10:41:02</td><td>1282635</td><td>Tulsīpur</td><td>20700</td><td>NP</td><td>28.131</td><td>82.2973</td><td>309.62</td><td>309.62</td><td>309.62</td><td>1001</td><td>18</td><td>10000</td><td>null</td><td>249</td><td>2.89</td><td>null</td><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr><tr><td>1686134463</td><td>2023-06-07 10:41:03</td><td>1282665</td><td>Tikoli</td><td>20700</td><td>NP</td><td>27.6333</td><td>84.5</td><td>314.85</td><td>314.85</td><td>314.85</td><td>997</td><td>14</td><td>10000</td><td>null</td><td>180</td><td>2.7</td><td>null</td><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr><tr><td>1686134456</td><td>2023-06-07 10:40:56</td><td>1282666</td><td>Ṭikāpur</td><td>20700</td><td>NP</td><td>28.5</td><td>81.1333</td><td>316.03</td><td>316.03</td><td>316.03</td><td>997</td><td>10</td><td>10000</td><td>null</td><td>243</td><td>2.84</td><td>null</td><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr></tbody></table></div>

# %%
# %sql
select * from weather_log_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>load_type</th><th>table_name</th><th>process_start_time</th><th>process_end_time</th><th>status</th><th>comments</th><th>start_date_time</th><th>end_date_time</th><th>created_on</th><th>created_by</th></tr></thead><tbody><tr><td>cf1dcb16-19bf-4b6a-82da-b1aa8cb94145</td><td>PROCESSED</td><td>processed_weather</td><td>2023-06-07T10:44:35.139+0000</td><td>2023-06-07T10:44:49.529+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-07T10:40:54.000+0000</td><td>2023-06-07T10:40:58.000+0000</td><td>2023-06-07T10:44:35.139+0000</td><td>Ujjwal Baral</td></tr><tr><td>c750c1f9-fa67-4add-9104-e63491ef38e0</td><td>RAW</td><td>raw_weather</td><td>2023-06-07T10:44:17.620+0000</td><td>2023-06-07T10:44:31.504+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-07T10:40:54.000+0000</td><td>2023-06-07T10:40:58.000+0000</td><td>2023-06-07T10:44:17.620+0000</td><td>Ujjwal Baral</td></tr><tr><td>02767f0b-de5c-4905-a387-6f38f72b0b48</td><td>RAW</td><td>raw_weather</td><td>2023-06-07T10:40:49.335+0000</td><td>2023-06-07T10:41:10.489+0000</td><td>COMPLETED</td><td>null</td><td>2023-06-07T10:40:54.000+0000</td><td>2023-06-07T10:40:58.000+0000</td><td>2023-06-07T10:40:49.335+0000</td><td>Ujjwal Baral</td></tr><tr><td>867b9dd3-2360-45b0-9f37-b485ef1f8f9b</td><td>RAW</td><td>raw_weather</td><td>2023-06-07T10:38:05.034+0000</td><td>null</td><td>EXTRACTING</td><td>null</td><td>null</td><td>null</td><td>2023-06-07T10:38:05.034+0000</td><td>Ujjwal Baral</td></tr></tbody></table></div>
